# %%
print("Hey I am good in coding and I also complete DSA in python")
# Out:
# Hey I am good in coding and I also complete DSA in python

# %%
## how to break line
print("Hey I am good in coding\nand I also complete DSA in python")
# Out:
# Hey I am good in coding
# and I also complete DSA in python

# %%
## double quotes

print("Hey I am good \"in coding\" and I also complete DSA in python")
# Out:
# Hey I am good "in coding" and I also complete DSA in python

# %%
## double quotes

print("Hey I am good \"in coding\"\nand I also complete DSA in python")
# Out:
# Hey I am good "in coding"
# and I also complete DSA in python

# %%
## seprator using till day

print("Ankur", 25, 15)
# Out:
# Ankur 25 15

# %%
## seprator using till day

print("Ankur", 25, 15, sep="~")
# Out:
# Ankur~25~15

# %%
## seprator using till day
## end parameter

print("Ankur", 25, 15, sep="~",end="23")
print("Harry")
# Out:
# Ankur~25~1523Harry

# %%
## seprator using till day
## end parameter

print("Ankur", 25, 15, sep="~",end="23\n")
print("Harry")
# Out:
# Ankur~25~1523
# Harry
