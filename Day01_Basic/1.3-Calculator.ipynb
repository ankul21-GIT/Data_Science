# %%
num1 = int(input("Enter the first number : "))
num2 = int(input("Enter the second number : "))

add = num1+num2
sub = num1-num2
mul = num1*num2
div = num1/num2
floordiv = num1//num2
mod = num1%num2
expon = num1**num2

print("The addition of num1 and num2 : ", add)
print("The subtraction of num1 and num2 : ", sub)
print("The multiplication of num1 and num2 : ", mul)
print("The division of num1 and num2 : ", div)
print("The floordiv of num1 and num2 : ", floordiv)
print("The modulous of num1 and num2 : ", mod)
print("The expon of num1 and num2 : ", expon)
# Out:
# The addition of num1 and num2 :  17
# The subtraction of num1 and num2 :  -1
# The multiplication of num1 and num2 :  72
# The division of num1 and num2 :  0.8888888888888888
# The floordiv of num1 and num2 :  0
# The modulous of num1 and num2 :  8
# The expon of num1 and num2 :  134217728
