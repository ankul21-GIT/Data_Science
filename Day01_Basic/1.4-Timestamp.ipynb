# %%
import time
# timestamp = time.strftime('%H:%m:%S')
# print(timestamp)
timestamp = time.strftime('%H')
print(timestamp)
timestamp = time.strftime('%M')
print(timestamp)
timestamp = time.strftime('%S')
print(timestamp)
# Out:
# 17
# 21
# 05

# %%
import time

timestamp = time.strftime('%H:%M:%S')
print("Full Timestamp:", timestamp)

hour = time.strftime('%H')
print("Hour:", hour)

minute = time.strftime('%M')
print("Minute:", minute)

second = time.strftime('%S')
print("Second:", second)
# Out:
# Full Timestamp: 17:21:05
# Hour: 17
# Minute: 21
# Second: 05

# %%
import time

timestamp = time.strftime('%H:%M:%S')  # Hour:Minute:Second
print(timestamp)
# Out:
# 17:21:05
