# %%
# Convert celsius to farenheit

celsius = int(input("Enter any positive number : "))

farenhiet = (celsius * 9/5)+32

print(f"{celsius} celsius is equal to {farenhiet} farenheit")
# Out:
# 37 celsius is equal to 98.6 farenheit
