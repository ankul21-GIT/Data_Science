# %% [markdown]
# # DataTypes
#
# 1. Definition:
#
# Data type specified the type of value a variable holds
#
# Data types are a classification of data which tell the compiler or interpreter how the programmer intends to use the data.
# They determine the type of operations that can be performed on the data, the values that the data can take, and the amount of memory needed to store the data.
#
# 2. Importance of Data Types in Programming
#
# Explanation:
#
# 1.Data types ensure that data is stored in an efficient way.
# 2.They help in performing correct operations on data.
# 3.Proper use of data types can prevent errors and bugs in the program.

# %%
a = 1
b = True
c = "Harry"
d = "None"
print("Type of a is : ",type(a))
print("Type of b is : ",type(b))
print("Type of c is : ",type(c))
# Out:
# Type of a is :  <class 'int'>
# Type of b is :  <class 'bool'>
# Type of c is :  <class 'str'>

# %%
age = 21
print(age,type(age))
# Out:
# 21 <class 'int'>

# %%
name = "Ankul"
print(type(name))
# Out:
# <class 'str'>

# %%
name = "Ankur"
age = 21
student = True
height = 23.4

print(name)
print(type(name))

print(age)
print(type(age))

print(student)
print(type(student))

print(height)
print(type(height))
# Out:
# Ankur
# <class 'str'>
# 21
# <class 'int'>
# True
# <class 'bool'>
# 23.4
# <class 'float'>

# %%
a = 10
b = 10
print(a==b)
print(type(a==b))
# Out:
# True
# <class 'bool'>

# %%
var = "hello" + "5"
print(var)
# Out:
# hello5

# %%
a = 10
print(a)
x = float(a)
print(x)
# Out:
# 10
# 10.0

# %%
name = "Ankur"
print(len(name))
# Out:
# 5

# %%
print("how are you sir")
print(len("what are you doing"))
# Out:
# how are you sir
# 18
