# %%
f = open('file44.txt', 'r')
while True:
    line = f.readline()
    print(line)
    if not line:
        print(line, type(line))
        break
# Out:
# I am a data science student
#
#  <class 'str'>

# %%
f = open('myfile9.txt', 'r')
i = 0
while True:
    i = i+1
    line = f.readline()
    if not line:
        break
    m1 = line.split(",")[0]
    m2 = line.split(",")[1]
    m3 = line.split(",")[2]
    print(f"Marks of student {i} in Math is: {m1}")
    print(f"Marks of student {i} in English is: {m2}")
    print(f"Marks of student {i} in SSt is: {m3}")
# Out:
# Marks of student 1 in Math is: 56
# Marks of student 1 in English is:  45
# Marks of student 1 in SSt is:  67
#
# Marks of student 2 in Math is: 12
# Marks of student 2 in English is:  34
# Marks of student 2 in SSt is:  63
#
# Marks of student 3 in Math is: 13
# Marks of student 3 in English is:  64
# Marks of student 3 in SSt is:  23

# %%
f = open('myfile444.txt', 'w')
lines = ['line 1\n', 'line 2\n', 'line 3\n']
f.writelines(lines)
f.close()
