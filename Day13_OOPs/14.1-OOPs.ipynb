# %% [markdown]
# # Classes and Objects:
#
# Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs. OOP allows for modeling real-world scenarios using classes and objects. This lesson covers the basics of creating classes and objects, including instance variables and methods.

# %%
### A class is a blue print for creating objects. Attributes,methods


## This is how you create a class


class Car:
    pass


# creating objects with class Car()

audi=Car()
bmw=Car()

print(type(audi))


# # class_2 

class Automobile:
    pass


RoyalEnfield=Automobile()

Tesla = Automobile()

print(type(RoyalEnfield))
# Out:
# <class '__main__.Car'>
# <class '__main__.Automobile'>

# %%
print(audi)
print(bmw)
print(Tesla)
print(RoyalEnfield)
# Out:
# <__main__.Car object at 0x000002685C7C3740>
# <__main__.Car object at 0x000002685C7C3A10>
# <__main__.Automobile object at 0x000002685C7C3B30>
# <__main__.Automobile object at 0x000002685B333440>

# %%
dir(bmw)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %% [markdown]
# we can modify the object porperties

# %%
## we can update the audi and bmw 4 window in audi car and we add 5 gear in BMW

audi.window = 4
bmw.gear = 5

print(audi.window)
print(bmw.gear)
# Out:
# 4
# 5

# %%
dir(bmw)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'gear']

# %%
### Instance Variable and Methods
class Dog:
    # constructor
    def __init__(self,name,age,colour):
        self.name = name
        self.age = age
        self.colour = colour
        
dog1 = Dog("Tyson",12,"Black")
print(dog1)

print(dog1.name)
print(dog1.age)
print(dog1.colour)

print()

dog2 = Dog("Lucy", 22, "Brown")
print(dog2.name)
print(dog2.age)
print(dog2.colour)
# Out:
# <__main__.Dog object at 0x000002685C7C3B60>
# Tyson
# 12
# Black
#
# Lucy
# 22
# Brown

# %%
## Define a class with instance method.

class Dog:
    def __init__(self,name,age,colour):
        self.name = name
        self.age = age
        self.colour = colour
        
    def bark(self):
        print(f"{self.name} is barking")
        
        print(f"The name is {self.name} and colour is {self.colour} and age is {self.age}")
          
          
dog1 = Dog("Tyson", 21, "White")
print(dog1.name)
print(dog1.age)
print(dog1.colour)
dog1.bark()
print()

dog2 = Dog("Muffien", 18, "Black")
print(dog2.name)
# Out:
# Tyson
# 21
# White
# Tyson is barking
# The name is Tyson and colour is White and age is 21
#
# Muffien

# %%
class Dog:
    def __init__(self,name,age,colour):
        self.name = name
        self.age = age
        self.colour = colour
        
    def bark(self):
        print(f"{self.name} is barking")
        
    def ages(self):
        print(f"The age of the dog is {self.age}")
          
          
dog1 = Dog("Tyson", 21, "White")
print(dog1.name) # you can comment it
dog1.bark()

print()
dog2 = Dog("Jaffer", 8, "Red")   
print(dog2.age)
dog2.bark()    
dog2.ages()
# Out:
# Tyson
# Tyson is barking
#
# 8
# Jaffer is barking
# The age of the dog is 8

# %%
class BankAccount :
    def __init__(self,owner,balance=0):
        self.owner = owner
        self.balance = balance
        
    def deposite(self,amount):
        self.balance += amount
        print(f"{amount} is deposited. new balance is {self.balance}")
        
    def withdraw(self,amount):
        if amount > self.balance:
            print("Insufficient amount")
        else:
            self.balance -= amount
            print(f"{amount} is withdra and new balance is {self.balance}")
            
    def get_balance(self):
        return self.balance
        
        
account =  BankAccount("Ankur", 5000)
print(account.balance)
print(account.owner)
print()
       
account.deposite(400)
account.withdraw(300)
print(account.get_balance())
# Out:
# 5000
# Ankur
#
# 400 is deposited. new balance is 5400
# 300 is withdra and new balance is 5100
# 5100

# %%
class Person:
  def __init__(mysillyobject, name, age):
    mysillyobject.name = name
    mysillyobject.age = age

  def myfunc(abc):
    print("Hello my name is " + abc.name)
  # def myfunc(self):
  #   print(f"Hello my name is {self.name}")

p1 = Person("John", 23)
print(p1.name)
p1.myfunc()
# Out:
# John
# Hello my name is John

# %% [markdown]
# Conclusion
#
# Object-Oriented Programming (OOP) allows you to model real-world scenarios using classes and objects. In this lesson, you learned how to create classes and objects, define instance variables and methods, and use them to perform various operations. Understanding these concepts is fundamental to writing effective and maintainable Python code.
