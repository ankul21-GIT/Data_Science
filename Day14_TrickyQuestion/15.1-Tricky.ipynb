# %%
a = int("20",4)
print(a)
# Out:
# 8

# %%
a = int("23",4)
print(a)
# Out:
# 11

# %%
a = int("33",4)
print(a)
# Out:
# 15

# %%
num = "4"+ "2"
val = int(num) + 6
print(float(val))
# Out:
# 48.0

# %%
a = "4"
b = "2"
print(a+b)
print(type(a+b))
# Out:
# 42
# <class 'str'>

# %%
nums = [1,2,3]
for i in nums:
    nums.append(i)
    if len(nums)>6:
        break
    
print(nums)
# Out:
# [1, 2, 3, 1, 2, 3, 1]

# %%
nums = [1,2,3]
for i in nums:
    nums.append(i)
    if len(nums)>6:
        break
    
    print(nums)
# Out:
# [1, 2, 3, 1]
# [1, 2, 3, 1, 2]
# [1, 2, 3, 1, 2, 3]

# %%
nums = [1,2,3,4,5,6]
for num in nums:
    if num == 3:
        break    
else:
    print("Loop Completed")

# %%
print(0.1 + 0.2 == 0.3)
# Out:
# False

# %%
print(0.1 + 0.2)
# Out:
# 0.30000000000000004
