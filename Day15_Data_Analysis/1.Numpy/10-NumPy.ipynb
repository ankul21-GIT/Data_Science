# %% [markdown]
# ## Broadcasting in NumPy array

# %%
import numpy as np
x1 = np.array([1,2,3,4])
x2 = np.array([1,2,3,4])
print(x1+x2)
# Out:
# [2 4 6 8]

# %%
var = np.array([[1],[2],[3]])
print(var)
print(var.ndim)
print(var.shape)
# Out:
# [[1]
#  [2]
#  [3]]
# 2
# (3, 1)

# %%
import numpy as np
x1 = np.array([1,2,3])

var = np.array([[1],[2],[3]])

print(x1)
print()
print(var)
print()
print(x1+var)
# Out:
# [1 2 3]
#
# [[1]
#  [2]
#  [3]]
#
# [[2 3 4]
#  [3 4 5]
#  [4 5 6]]

# %%
x = np.array([[1],[2]])
y = np.array([[1,2,3],[1,2,3]])
print(x+y)
# Out:
# [[2 3 4]
#  [3 4 5]]
