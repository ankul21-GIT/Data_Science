# %% [markdown]
# ## Data Structure in Pandas

# %% [markdown]
# Series : it is define as a one-dimensional array that is capable of storing various data type.

# %% [markdown]
# import pandas as pd
#
# a = pd.Series()
#
# print(a)

# %%
import pandas as pd
x = [1,2,3,4,5]
var = pd.Series(x)
print(var)
print(type(var))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
## how to get a index number

import pandas as pd
x = [1,2,3,4,5]
var = pd.Series(x)
print(var)
print(var[4])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 5

# %%
## how to give a new index 

import pandas as pd
x = [1,2,3,4,5]
var = pd.Series(x,index=['a','s','d','f','e'])
print(var)
print(var[4])
# Out:
# a    1
# s    2
# d    3
# f    4
# e    5
# dtype: int64
# 5
# C:\Users\Ankul\AppData\Local\Temp\ipykernel_11360\872592777.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(var[4])

# %%
## How to change data type using (dtype="eg")

import pandas as pd
x = [1,2,3,4,5]
var = pd.Series(x,index=['a','s','d','f','e'],dtype="float")
print(var)
print(var[4])
# Out:
# a    1.0
# s    2.0
# d    3.0
# f    4.0
# e    5.0
# dtype: float64
# 5.0
# C:\Users\Ankul\AppData\Local\Temp\ipykernel_11360\796164682.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(var[4])

# %%
## how to give name into the datatype using name method

import pandas as pd
x = [1,2,3,4,5]
var = pd.Series(x,index=['a','s','d','f','e'],dtype="float",name="python")
print(var)
print(var[4])
# Out:
# a    1.0
# s    2.0
# d    3.0
# f    4.0
# e    5.0
# Name: python, dtype: float64
# 5.0
# C:\Users\Ankul\AppData\Local\Temp\ipykernel_11360\1145243253.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(var[4])

# %%
dic = {"name":['pythin','c','c++','java'],"por":[12,13,14,15],"rank":[1,4,3,2]}
var = pd.Series(dic)
print(var)
# Out:
# name    [pythin, c, c++, java]
# por           [12, 13, 14, 15]
# rank              [1, 4, 3, 2]
# dtype: object

# %%
s = pd.Series(12)
print(s)
print(type(s))
# Out:
# 0    12
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
## How to give multiple series using index method

s = pd.Series(12,index=[1,2,3,4,5])
print(s)
print(type(s))
# Out:
# 1    12
# 2    12
# 3    12
# 4    12
# 5    12
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
s1 = pd.Series(12,index=[1,2,3,4,5,6,7])
s2 = pd.Series(12,index=[1,2,3,4])
print(s1+s2)
# Out:
# 1    24.0
# 2    24.0
# 3    24.0
# 4    24.0
# 5     NaN
# 6     NaN
# 7     NaN
# dtype: float64
