# %% [markdown]
# Pandas-DataFrame And Series :
#
# Pandas is a powerful data manipulation library in Python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame. A Series is a one-dimensional array-like object, while a DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns).

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
## Series
##A Pandas Series is a one-dimensional array-like object that can hold any data type. It is similar to a column in a table.

import pandas as pd

data = [1,2,3,4,5]
series = pd.Series(data)
print(series)
print(type(series))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# crete a series from dictionary

data = {"a":1,"b":2,"c":3,"d":4,"e":5}
series = pd.Series(data)
print(series)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data = [10,20,30,40,50]
stri = ['i','ii','iii','iv','v']
series = pd.Series(data,index=stri)
print(series)
# Out:
# i      10
# ii     20
# iii    30
# iv     40
# v      50
# dtype: int64

# %%
name = {
    "name" : "ankur",
    "age": 23,
    "sec" : 24,
    "gender": "mle",
}

series = pd.Series(name)
print(series)
# Out:
# name      ankur
# age          23
# sec          24
# gender      mle
# dtype: object

# %%
## Dataframe
## create a Dataframe from a dictionary of list

name = {
    "Name":["John","Bob","Casey","David"],
    "Age":[23,45,67,32],
    "City":["New York","California","Chicago","Houston"]

}

series = pd.DataFrame(name)
print(series)
# Out:
#     Name  Age        City
# 0   John   23    New York
# 1    Bob   45  California
# 2  Casey   67     Chicago
# 3  David   32     Houston

# %%
## Create a Data frame From a List of Dictionaries

data = [
    {"Name":"Ankur","Age":25,"country":"India","Profession":"Data Science"},
    {"Name":"Abhishek","Age":21,"country":"India","Profession":"Web Developer"},
    {"Name":"Lucy","Age":29,"country":"America","Profession":"Software Engineer"},
    {"Name":"Bob","Age":32,"country":"canada","Profession":"Machicine Learning"},
    {"Name":"Casey","Age":27,"country":"Australia","Profession":"Prompt Engineer"}
   
]

name = pd.DataFrame(data)
print(name)
# Out:
#        Name  Age    country          Profession
# 0     Ankur   25      India        Data Science
# 1  Abhishek   21      India       Web Developer
# 2      Lucy   29    America   Software Engineer
# 3       Bob   32     canada  Machicine Learning
# 4     Casey   27  Australia     Prompt Engineer

# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ankul\Downloads\sales_data.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(r"C:\Users\ankul\Downloads\sales_data.csv")
#       4 df.head()
#
# ...

# %%
df_2 = pd.read_excel(r"C:\Users\ankul\Downloads\sales_data.xlsx")
df_2

# %%
df_2.describe()

# %%
df_2.info()

# %%
df_2.tail(10)

# %%
data = pd.DataFrame({"Brand":["Maruti","Hyundai","Tata","Mahindra","Maruti","Hyundai","Renault","Tata","Maruti"],
                     "Years": [2012,2014,2011,2015,2012,2016,2014,2018,2019],
                     "kms driven": [50000,30000,60000,25000,10000,46000,31000,15000,12000],
                     "City": ["Gurgaon","Mumbai","Delhi","Delhi","Mumbai","Delhi","Mumbai","Chennai","Ghaziabad"],
                     "Mileage" : [28,27,25,26,28,29,24,21,24]})

display(data)

# %%
display(data.loc[(data.Brand=="Maruti") & (data.Mileage >= 25)])

# %%
display(data.iloc[[0,2,4,7]])

# %%
df = pd.read_csv(r"C:\Users\ankul\Downloads\sales_data.csv")
df.head()

# %%
df.loc[0]

# %%
## Create a Data frame From a List of Dictionaries

data=[
    {'Name':'Abhishek','Age':30,'City':'Bangalore'},
    {'Name':'John','Age':31,'City':'New York'},
    {'Name':'Bappy','Age':32,'City':'Florida'},
    {'Name':'JAck','Age':33,'City':'Pune'}
    
]
df=pd.DataFrame(data)

print(type(df))
df

# %%
## Accessing a specified element
df.at[2,"Age"]

# %%
df.at[3,"City"]

# %%
df.iat[2,2]

# %%
df

# %% [markdown]
# Data Manipulation with data frame

# %%
## Insert a column or add a column

df['Salary'] = [60000,75000,68000,80000]
df

# %%
## remove or delete column

df.drop('Salary', axis=1, inplace=True)
df

# %%
df['Age'] = df['Age'] + 1

# %%
df

# %%
df.drop(0,inplace=True)

# %%
df

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ankul\Downloads\sales_data.csv")
df.head()
