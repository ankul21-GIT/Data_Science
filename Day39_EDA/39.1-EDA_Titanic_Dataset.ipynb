# %% [markdown]
# # Titanic Data Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Why we do EDA**
#
# - Model Bulding.
# - Analysis and reporting.
# - Validate Assumptions.
# - Handling missing values.
# - Feature Enginnering.
# - Detect Outlier.

# %%
df = pd.read_csv("C:\\Users\\Ankul\Desktop\\train.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Ankul\AppData\Local\Temp\ipykernel_12188\1954803851.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv("C:\\Users\\Ankul\Desktop\\train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **EDA is an iterative process**

# %% [markdown]
# **Column Type**
#
# - **Numerical** - Age,Fare,PasengerID
# - **Categorical** - Survived,Pclass,Sex,SibSp,Parched,Embarked
# - **Mixed** - Name,Ticket,Cabin

# %% [markdown]
# **Univariate Analysis**
#
# Univariate analysis focuses on analyzing each feature in the dataset independently.
#
# - **Distribution analysis:** The distribution of each feature is examined to identify its shape, central tendency, and dispersion.
#
# - **Identifying potential issues:** Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values.

# %% [markdown]
# The shape of a data distribution refers to its overall pattern or form as it is represented on a graph. Some common shapes of data distributions include:
#
# - **Normal Distribution:** A symmetrical and bell-shaped distribution where the mean, median, and mode are equal and the majority of the data falls in the middle of the distribution with gradually decreasing frequencies towards the tails.
#
# - **Skewed Distribution:**  A distribution that is not symmetrical, with one tail being longer than the other. It can be either positively skewed (right-skewed) or negatively skewed (left-skewed).
#
# - **Bimodal Distribution:**  A distribution with two peaks or modes.
#
# - **Uniform Distribution:**  A distribution where all values have an equal chance of occurring.
# - **Conclusion:** Summarize the finding of the EDA and make decision about how to proceed with further analysis.

# %% [markdown]
# **Age**
#
# Conclusion
#
# - Age is normally(almost) distributed.
# - 20% of the value is missing.
# - There are some outlier.

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind='hist')
plt.show()

# %%
df['Age'].plot(kind='hist',bins=20)
plt.show()

# %%
df['Age'].plot(kind='kde')
plt.show()

# %%
#### skew() - skew method show the how much the data is distributed. when the data is neat to zero it mean it is normally distributed.
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
## how to draw the box plot.

df['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Age'] > 65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(177)

# %%
## How to find total value in data. output is 0.19 it means 19 percent is missing value in data.
df['Age'].isnull().sum()/len(df['Age'])
# Out:
# np.float64(0.19865319865319866)

# %% [markdown]
# **Fare**
#
# Conclusion
#
# - The data is highly(positively) skewed
# - Fare col actually contains the group fare and not the individual fare(This might be and issue)
# - We need to create a new col called individual fare

# %%
df['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df['Fare'].head()
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %%
df['Fare'].tail()
# Out:
# 886    13.00
# 887    30.00
# 888    23.45
# 889    30.00
# 890     7.75
# Name: Fare, dtype: float64

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Fare'].plot(kind='kde')
plt.show()

# %%
## check how much data is skewed.
df['Fare'].skew()
# Out:
# np.float64(4.787316519674893)

# %%
df['Fare'].plot(kind="box")
# Out:
# <Axes: >

# %%
### There are 200 passenger there fare are greater than 200
df[df['Fare'] > 200]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 258          259         1       1
# 299          300         1       1
# 311          312         1       1
# 341          342         1       1
# 377          378         0       1
# 380          381         1       1
# 438          439         0       1
# 527          528         0       1
# 557          558         0       1
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 716          717         1       1
# 730          731         1       1
# 737          738         1       1
# 742          743         1       1
# 779          780         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ...

# %%
### There are 300 passenger there fare are greater than 300.
df[df['Fare'] > 300]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
df['Fare'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df['Fare'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Steps of doing Univariate Analysis on Categorical columns**
#
# **Descriptive Statistics:** Compute the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# **Visualizations:** Create visualizations to explore the distribution of the categories. Some common visualizations for categorical data include count plots and pie charts. These visualizations provide a visual representation of the distribution of the categories and can help identify any patterns or anomalies in the data.
#
# **Missing Values:** Check for missing values in the data and decide how to handle them. Missing values can be imputed or excluded from the analysis, depending on the research question and the data set.
#
# **Conclusion:** Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# **Survived**
#
# Conclusion

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
plt.show()

# %%
## if you wanna know about in term of percentage.
df['Survived'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
### find the missing value.
df['Survived'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Pclass**

# %%
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind='bar',color='r')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **Sex Columns**

# %%
df['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
### in term of percentage
df['Sex'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **SibSp**

# %%
df['SibSp']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
# Name: SibSp, Length: 891, dtype: int64

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['SibSp'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SibSp'>

# %%
df['SibSp'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **Parch**
#
# Conclusion
#
# - Parch and SibSp cols can be merged to form a new col call a family_size.
# - Create a new column called is_alone.

# %%
df['Parch']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    2
# 889    0
# 890    0
# Name: Parch, Length: 891, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df['Parch'].value_counts().plot(kind='bar')
plt.show()

# %%
df['Parch'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **Embarked**

# %%
df['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind='bar',color='r')
# Out:
# <Axes: xlabel='Embarked'>

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **Steps of doing Bivariate Analysis**
#
# Select 2 cols
#
# Understand type of relationship
#
# **Numerical - Numerical**
# 1. You can plot graphs like scatterplot (regression plots), 2D histplot, 2D KDEplots
# 2. Check correlation coefficient to check linear relationship
#
# **Numerical - Categorical -** create visualizations that compare the distribution of the numerical data across different categories of the categorical data.
# 1. You can plot graphs like barplot, boxplot, kdeplot, violinplot even scatterplots
#
# **Categorical - Categorical**
# 1. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.
# 2. You can plots like heatmap, stacked barplots, treemaps
#
# Write your conclusions
#
# - P3 class is more dangerous.
# - p1 class is more safer.

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.crosstab(df['Survived'],df['Pclass'])
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
pd.crosstab(df['Survived'],df['Pclass'], normalize='columns')
# Out:
# Pclass          1         2         3
# Survived
# 0         0.37037  0.527174  0.757637
# 1         0.62963  0.472826  0.242363

# %%
pd.crosstab(df['Survived'],df['Pclass'], normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
sns.heatmap(pd.crosstab(df['Survived'],df['Pclass'], normalize='columns')*100)
plt.show()

# %% [markdown]
# Survived(sex)

# %%
pd.crosstab(df['Survived'],df['Sex'])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
pd.crosstab(df['Survived'],df['Sex'], normalize='columns')
# Out:
# Sex         female      male
# Survived
# 0         0.257962  0.811092
# 1         0.742038  0.188908

# %%
pd.crosstab(df['Survived'],df['Sex'], normalize='columns')*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
sns.heatmap(pd.crosstab(df['Survived'],df['Sex'], normalize='columns')*100)
plt.show()

# %% [markdown]
# Survived(Embarked)

# %%
pd.crosstab(df['Survived'],df['Embarked'])
# Out:
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217

# %%
pd.crosstab(df['Survived'],df['Embarked'], normalize='columns')
# Out:
# Embarked         C        Q         S
# Survived
# 0         0.446429  0.61039  0.663043
# 1         0.553571  0.38961  0.336957

# %%
pd.crosstab(df['Survived'],df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
sns.heatmap(pd.crosstab(df['Survived'],df['Embarked'], normalize='columns')*100)
plt.show()

# %%
###  Cherbourg 43 percentage female board to titanic and 56 percent male
pd.crosstab(df['Sex'],df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
### 50 percent people travel in P1 class from cherbourg
pd.crosstab(df['Pclass'],df['Embarked'], normalize='columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %% [markdown]
# Survived and age
#
# Conclusion
#
# - If you are child your chance of survive is higher than your chance of dying

# %%
## find those passenger who are alive 

df[df['Survived'] == 1]['Age'].plot(kind='kde', label='Survived')
df[df['Survived'] == 0]['Age'].plot(kind='kde', label='Not Survived')

plt.legend()
plt.show()

# %%
df[df['Pclass'] == 1]['Age'].mean()
# Out:
# np.float64(38.233440860215055)

# %% [markdown]
# Feature Engineering

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df[df['SibSp'] == 8]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
## calculate total cost of each person.

69.55/11
# Out:
# 6.322727272727272

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#      Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159  NaN      8      2  CA. 2343  69.55   NaN        S
# 180  NaN      8      2  CA. 2343  69.55   NaN        S
# 201  NaN      8      2  CA. 2343  69.55   NaN        S
# 324  NaN      8      2  CA. 2343  69.55   NaN        S
# 792  NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
## how many people in sage family.

df[df['Name'].str.contains('Sage')]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 641          642         1       1               Sagesser, Mlle. Emma  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked
# 159   NaN      8      2  CA. 2343  69.55   NaN        S
# 180   NaN      8      2  CA. 2343  69.55   NaN        S
# 201   NaN      8      2  CA. 2343  69.55   NaN        S
# ...

# %%
df1 = pd.read_csv("C:\\Users\\Ankul\Desktop\\test.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Ankul\AppData\Local\Temp\ipykernel_12188\1493227767.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df1 = pd.read_csv("C:\\Users\\Ankul\Desktop\\test.csv")

# %%
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df = pd.concat([df,df1])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Ticket'] == 'CA. 2343']
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160       0.0       3         Sage, Master. Thomas Henry    male
# 180          181       0.0       3       Sage, Miss. Constance Gladys  female
# 201          202       0.0       3                Sage, Mr. Frederick    male
# 324          325       0.0       3           Sage, Mr. George John Jr    male
# 792          793       0.0       3            Sage, Miss. Stella Anna  female
# 846          847       0.0       3           Sage, Mr. Douglas Bullen    male
# 863          864       0.0       3  Sage, Miss. Dorothy Edith "Dolly"  female
# 188         1080       NaN       3                    Sage, Miss. Ada  female
# 342         1234       NaN       3              Sage, Mr. John George    male
# 360         1252       NaN       3        Sage, Master. William Henry    male
# 365         1257       NaN       3     Sage, Mrs. John (Annie Bullen)  female
#
# ...

# %%
df['Ticket'].value_counts()
# Out:
# Ticket
# CA. 2343        11
# 1601             8
# CA 2144          8
# 347082           7
# S.O.C. 14879     7
#                 ..
# A.5. 3236        1
# 347086           1
# 365237           1
# 334915           1
# 28666            1
# Name: count, Length: 929, dtype: int64

# %%
df[df['Ticket'] == 'CA 2144']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 59            60       0.0       3       Goodwin, Master. William Frederick
# 71            72       0.0       3               Goodwin, Miss. Lillian Amy
# 386          387       0.0       3          Goodwin, Master. Sidney Leonard
# 480          481       0.0       3           Goodwin, Master. Harold Victor
# 678          679       0.0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
# 683          684       0.0       3              Goodwin, Mr. Charles Edward
# 139         1031       NaN       3           Goodwin, Mr. Charles Frederick
# 140         1032       NaN       3              Goodwin, Miss. Jessie Allis
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 59     male  11.0      5      2  CA 2144  46.9   NaN        S
# 71   female  16.0      5      2  CA 2144  46.9   NaN        S
# 386    male   1.0      5      2  CA 2144  46.9   NaN        S
# ...

# %%
df['Fare']/(df['SibSp']+ df['Parch']+ 1)
# Out:
# 0        3.625000
# 1       35.641650
# 2        7.925000
# 3       26.550000
# 4        8.050000
#           ...
# 413      8.050000
# 414    108.900000
# 415      7.250000
# 416      8.050000
# 417      7.452767
# Length: 1309, dtype: float64

# %%
### how to find the individual fair

df['individual_fair'] = df['Fare']/(df['SibSp'] + df['Parch'] + 1)

# %%
df['individual_fair']
# Out:
# 0        3.625000
# 1       35.641650
# 2        7.925000
# 3       26.550000
# 4        8.050000
#           ...
# 413      8.050000
# 414    108.900000
# 415      7.250000
# 416      8.050000
# 417      7.452767
# Name: individual_fair, Length: 1309, dtype: float64

# %%
df['individual_fair'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[['individual_fair','Fare']].describe()
# Out:
#        individual_fair         Fare
# count      1308.000000  1308.000000
# mean         20.518215    33.295479
# std          35.774337    51.758668
# min           0.000000     0.000000
# 25%           7.452767     7.895800
# 50%           8.512483    14.454200
# 75%          24.237500    31.275000
# max         512.329200   512.329200

# %% [markdown]
# second feature engineering

# %%
df['family_size'] = df['SibSp'] + df['Parch'] + 1

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# now we are going to add new features
# 1. 1 - Alone - (if he is travelling alone)
# 2. 2 to 4 - (small family)
# 3. gretaer than 5 - large family

# %%
def transform_family_size(num):
    if num ==1:
        return 'alone'
    elif num>1 and num<5:
        return 'small family'
    else:
        return 'Large family'

# %%
df['family_type'] = df['family_size'].apply(transform_family_size)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# bivariate analysis

# %%
pd.crosstab(df['Survived'], df['family_type'], normalize='columns')
# Out:
# family_type  Large family     alone  small family
# Survived
# 0.0               0.83871  0.696462      0.421233
# 1.0               0.16129  0.303538      0.578767

# %%
## If you are travelling with large family 80 percent chance of your death.
pd.crosstab(df['Survived'], df['family_type'], normalize='columns') * 100
# Out:
# family_type  Large family      alone  small family
# Survived
# 0.0             83.870968  69.646182     42.123288
# 1.0             16.129032  30.353818     57.876712

# %%
df['Name'].str.split()
# Out:
# 0                           [Braund,, Mr., Owen, Harris]
# 1      [Cumings,, Mrs., John, Bradley, (Florence, Bri...
# 2                             [Heikkinen,, Miss., Laina]
# 3      [Futrelle,, Mrs., Jacques, Heath, (Lily, May, ...
# 4                          [Allen,, Mr., William, Henry]
#                              ...
# 413                               [Spector,, Mr., Woolf]
# 414                   [Oliva, y, Ocana,, Dona., Fermina]
# 415                    [Saether,, Mr., Simon, Sivertsen]
# 416                              [Ware,, Mr., Frederick]
# 417                        [Peter,, Master., Michael, J]
# Name: Name, Length: 1309, dtype: object

# %%
## how to get the sirname of the name using zero

df['Name'].str.split().str.get(0)
# Out:
# 0         Braund,
# 1        Cumings,
# 2      Heikkinen,
# 3       Futrelle,
# 4          Allen,
#           ...
# 413      Spector,
# 414         Oliva
# 415      Saether,
# 416         Ware,
# 417        Peter,
# Name: Name, Length: 1309, dtype: object

# %%
## create a new column and the name of the new column is sirname


df['sirname'] = df['Name'].str.split().str.get(0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
## how to get a sir name like mr or mrs
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 413                                   Spector, Mr. Woolf
# 414                         Oliva y Ocana, Dona. Fermina
# 415                         Saether, Mr. Simon Sivertsen
# 416                                  Ware, Mr. Frederick
# 417                             Peter, Master. Michael J
# Name: Name, Length: 1309, dtype: object

# %%
df['Name'].str.split(',')
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 413                                [Spector,  Mr. Woolf]
# 414                      [Oliva y Ocana,  Dona. Fermina]
# 415                      [Saether,  Mr. Simon Sivertsen]
# 416                               [Ware,  Mr. Frederick]
# 417                          [Peter,  Master. Michael J]
# Name: Name, Length: 1309, dtype: object

# %%
df['Name'].str.split(',').str.get(1)
# Out:
# 0                                  Mr. Owen Harris
# 1       Mrs. John Bradley (Florence Briggs Thayer)
# 2                                      Miss. Laina
# 3               Mrs. Jacques Heath (Lily May Peel)
# 4                                Mr. William Henry
#                           ...
# 413                                      Mr. Woolf
# 414                                  Dona. Fermina
# 415                            Mr. Simon Sivertsen
# 416                                  Mr. Frederick
# 417                              Master. Michael J
# Name: Name, Length: 1309, dtype: object

# %%
## there is a extra space so we use strip method to remove extra space
df['Name'].str.split(',').str.get(1).str.strip()
# Out:
# 0                                 Mr. Owen Harris
# 1      Mrs. John Bradley (Florence Briggs Thayer)
# 2                                     Miss. Laina
# 3              Mrs. Jacques Heath (Lily May Peel)
# 4                               Mr. William Henry
#                           ...
# 413                                     Mr. Woolf
# 414                                 Dona. Fermina
# 415                           Mr. Simon Sivertsen
# 416                                 Mr. Frederick
# 417                             Master. Michael J
# Name: Name, Length: 1309, dtype: object

# %%
df['Name'].str.split(',').str.get(1).str.strip().str.split(' ')
# Out:
# 0                                    [Mr., Owen, Harris]
# 1      [Mrs., John, Bradley, (Florence, Briggs, Thayer)]
# 2                                         [Miss., Laina]
# 3              [Mrs., Jacques, Heath, (Lily, May, Peel)]
# 4                                  [Mr., William, Henry]
#                              ...
# 413                                         [Mr., Woolf]
# 414                                     [Dona., Fermina]
# 415                              [Mr., Simon, Sivertsen]
# 416                                     [Mr., Frederick]
# 417                                [Master., Michael, J]
# Name: Name, Length: 1309, dtype: object

# %%
## now we get the title
df['Name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0)
# Out:
# 0          Mr.
# 1         Mrs.
# 2        Miss.
# 3         Mrs.
# 4          Mr.
#         ...
# 413        Mr.
# 414      Dona.
# 415        Mr.
# 416        Mr.
# 417    Master.
# Name: Name, Length: 1309, dtype: object

# %%
df['title'] = df['Name'].str.split().str.get(1).str.strip().str.split().str.get(0)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['title'].value_counts()
# Out:
# title
# Mr.             736
# Miss.           256
# Mrs.            191
# Master.          59
# Rev.              8
# Dr.               8
# y                 8
# Planke,           4
# Col.              4
# Billiard,         3
# Impe,             3
# Carlo,            2
# Mlle.             2
# Gordon,           2
# Major.            2
# Messemaeker,      2
# Ms.               2
# Walle,            1
# Mme.              1
# Steen,            1
# Pelsmaeker,       1
# Mulder,           1
# der               1
# Don.              1
# Capt.             1
# Velde,            1
# the               1
# Shawah,           1
# Jonkheer.         1
# Melkebeke,        1
# Cruyssen,         1
# Khalil,           1
# Palmquist,        1
# Brito,            1
# Name: count, dtype: int64

# %%
df['title'] = df['title'].str.replace('Rev', 'other')
df['title'] = df['title'].str.replace('Dr.', 'other')
df['title'] = df['title'].str.replace('Col.', 'other')
df['title'] = df['title'].str.replace('Major.', 'other')
df['title'] = df['title'].str.replace('Capt.', 'other')
df['title'] = df['title'].str.replace('the.', 'other')
df['title'] = df['title'].str.replace('Jonkheer', 'other')

# %%
df[df['title'].isin(['Mr.','Miss.','Mrs.','Master.','other'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 412         1304       NaN       3
# 413         1305       NaN       3
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
temp_df = df[df['title'].isin(['Mr.','Miss.','Mrs.','Master.','other'])]

# %%
pd.crosstab(temp_df['Survived'], temp_df['title'])
# Out:
# title     Master.  Miss.  Mr.  Mrs.  other
# Survived
# 0.0            17     53  423    24      7
# 1.0            23    126   79    97      5

# %%
pd.crosstab(temp_df['Survived'], temp_df['title'], normalize='columns')
# Out:
# title     Master.     Miss.       Mr.      Mrs.     other
# Survived
# 0.0         0.425  0.296089  0.842629  0.198347  0.583333
# 1.0         0.575  0.703911  0.157371  0.801653  0.416667

# %%
## if you are Mrs 80 percent chance of you are safe 
pd.crosstab(temp_df['Survived'], temp_df['title'], normalize='columns') * 100
# Out:
# title     Master.      Miss.        Mr.       Mrs.      other
# Survived
# 0.0          42.5  29.608939  84.262948  19.834711  58.333333
# 1.0          57.5  70.391061  15.737052  80.165289  41.666667

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Cabin'].isnull().sum()
# Out:
# np.int64(1014)

# %%
df['Cabin'].isnull().sum()/len(df['Cabin'])
# Out:
# np.float64(0.774637127578304)

# %%
df['Cabin'].isnull().sum()/len(df['Cabin']) * 100
# Out:
# np.float64(77.46371275783041)

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F4                 4
#                   ..
# C39                1
# B24                1
# D40                1
# D38                1
# C105               1
# Name: count, Length: 186, dtype: int64

# %%
df['Cabin'].value_counts().head(15)
# Out:
# Cabin
# C23 C25 C27        6
# G6                 5
# B57 B59 B63 B66    5
# F33                4
# F4                 4
# C78                4
# D                  4
# F2                 4
# B96 B98            4
# C22 C26            4
# A34                3
# E34                3
# C101               3
# B51 B53 B55        3
# E101               3
# Name: count, dtype: int64

# %%
df['Cabin'].fillna('M')
# Out:
# 0         M
# 1       C85
# 2         M
# 3      C123
# 4         M
#        ...
# 413       M
# 414    C105
# 415       M
# 416       M
# 417       M
# Name: Cabin, Length: 1309, dtype: object

# %%
df['Cabin'].fillna('M',inplace=True)

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# M                  1014
# C23 C25 C27           6
# G6                    5
# B57 B59 B63 B66       5
# F33                   4
#                    ...
# C39                   1
# B24                   1
# D40                   1
# D38                   1
# C105                  1
# Name: count, Length: 187, dtype: int64

# %%
df['deck'] = df['Cabin'].str[0]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['deck'].value_counts()
# Out:
# deck
# M    1014
# C      94
# B      65
# D      46
# E      41
# A      22
# F      21
# G       5
# T       1
# Name: count, dtype: int64

# %%
pd.crosstab(df['Pclass'],df['deck'])
# Out:
# deck     A   B   C   D   E   F  G    M  T
# Pclass
# 1       22  65  94  40  34   0  0   67  1
# 2        0   0   0   6   4  13  0  254  0
# 3        0   0   0   0   3   8  5  693  0

# %%
pd.crosstab(df['deck'],df['Pclass'])
# Out:
# Pclass   1    2    3
# deck
# A       22    0    0
# B       65    0    0
# C       94    0    0
# D       40    6    0
# E       34    4    3
# F        0   13    8
# G        0    0    5
# M       67  254  693
# T        1    0    0

# %%
pd.crosstab(df['Survived'],df['deck'])
# Out:
# deck      A   B   C   D   E  F  G    M  T
# Survived
# 0.0       8  12  24   8   8  5  2  481  1
# 1.0       7  35  35  25  24  8  2  206  0

# %%
pd.crosstab(df['Survived'],df['deck'], normalize='columns')
# Out:
# deck             A         B        C         D     E         F    G  \
# Survived
# 0.0       0.533333  0.255319  0.40678  0.242424  0.25  0.384615  0.5
# 1.0       0.466667  0.744681  0.59322  0.757576  0.75  0.615385  0.5
#
# deck             M    T
# Survived
# 0.0       0.700146  1.0
# 1.0       0.299854  0.0

# %%
pd.crosstab(df['Survived'],df['deck'], normalize='columns') * 100
# Out:
# deck              A          B          C          D     E          F     G  \
# Survived
# 0.0       53.333333  25.531915  40.677966  24.242424  25.0  38.461538  50.0
# 1.0       46.666667  74.468085  59.322034  75.757576  75.0  61.538462  50.0
#
# deck              M      T
# Survived
# 0.0       70.014556  100.0
# 1.0       29.985444    0.0

# %%
pd.crosstab(df['deck'],df['Survived'],normalize='index').plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='deck'>

# %%
df.corr(numeric_only=True)['Survived']
# Out:
# PassengerId       -0.005007
# Survived           1.000000
# Pclass            -0.338481
# Age               -0.077221
# SibSp             -0.035322
# Parch              0.081629
# Fare               0.257307
# individual_fair    0.221600
# family_size        0.016639
# Name: Survived, dtype: float64

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
sns.pairplot(df1)
